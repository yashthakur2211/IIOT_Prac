# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_excel('./arduino_nano_uno.xlsx')
data.head()
# Out:
#     0:00:00 AM  23  88  21  87  24  88.1  21.1  89
# 0   1:00:00 AM  22  89  22  89  21    91    24  92
# 1   2:00:00 AM  25  92  22  91  25    92    25  92
# 2   3:00:00 AM  26  95  25  96  26    97    25  97
# 3   4:00:00 AM  27  95  27  95  25    95    26  94
# 4   5:00:00 AM  26  89  27  90  27    90    27  89

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2016 entries, 0 to 2015
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0    0:00:00 AM  2016 non-null   object
#  1   23           2016 non-null   int64
#  2   88           2016 non-null   int64
#  3   21           2016 non-null   int64
#  4   87           2016 non-null   int64
#  5   24           2016 non-null   int64
#  6   88.1         2016 non-null   int64
#  7   21.1         2016 non-null   int64
#  8   89           2016 non-null   int64
# dtypes: int64(8), object(1)
# memory usage: 141.9+ KB

# %%
data.describe()
# Out:
#                 23           88           21           87           24
# count  2016.000000  2016.000000  2016.000000  2016.000000  2016.000000  \
# mean     27.321925    80.501488    27.325397    80.336310    27.324901
# std       3.278479     9.669014     3.280179     9.570011     3.274550
# min      21.000000    63.000000    21.000000    63.000000    21.000000
# 25%      25.000000    72.000000    25.000000    72.000000    25.000000
# 50%      27.000000    82.000000    27.000000    82.000000    27.000000
# 75%      30.000000    88.000000    30.000000    88.000000    30.000000
# max      34.000000    97.000000    33.000000    96.000000    33.000000
#
#               88.1         21.1           89
# count  2016.000000  2016.000000  2016.000000
# mean     80.520337    27.336806    80.481647
# std       9.732939     3.258911     9.679410
# min      63.000000    21.000000    63.000000
# 25%      72.000000    25.000000    72.000000
# 50%      82.000000    27.000000    82.000000
# 75%      88.000000    30.000000    88.000000
# max      97.000000    33.000000    97.000000

# %%
data.columns=['Time','Humidity Readings 1','Temeperature 1','Humidity Readings 2','Temeperature 2','Humidity Readings 3','Temeperature 3','Humidity Readings 4','Temeperature 4']

# %%
data.head()
# Out:
#           Time  Humidity Readings 1  Temeperature 1  Humidity Readings 2
# 0   1:00:00 AM                   22              89                   22  \
# 1   2:00:00 AM                   25              92                   22
# 2   3:00:00 AM                   26              95                   25
# 3   4:00:00 AM                   27              95                   27
# 4   5:00:00 AM                   26              89                   27
#
#    Temeperature 2  Humidity Readings 3  Temeperature 3  Humidity Readings 4
# 0              89                   21              91                   24  \
# 1              91                   25              92                   25
# 2              96                   26              97                   25
# 3              95                   25              95                   26
# 4              90                   27              90                   27
#
#    Temeperature 4
# 0              92
# 1              92
# 2              97
# 3              94
# 4              89

# %%
day_data=data.iloc[23:47,:]
day_data.tail()
# Out:
#             Time  Humidity Readings 1  Temeperature 1  Humidity Readings 2
# 42    7:00:00 PM                   25              83                   27  \
# 43    8:00:00 PM                   26              85                   26
# 44    9:00:00 PM                   24              86                   25
# 45   10:00:00 PM                   24              88                   25
# 46   11:00:00 PM                   23              86                   23
#
#     Temeperature 2  Humidity Readings 3  Temeperature 3  Humidity Readings 4
# 42              85                   26              84                   27  \
# 43              85                   26              84                   25
# 44              86                   26              87                   24
# 45              89                   25              86                   24
# 46              89                   23              88                   22
#
#     Temeperature 4
# 42              84
# 43              84
# 44              87
# 45              88
# 46              86

# %%
plt.figure(figsize=(30,10))
plt.plot(day_data['Time'],day_data['Temeperature 1'],marker='o',linestyle='-')
plt.show()

# %%
plt.figure(figsize=(30,10))
plt.plot(day_data['Time'],day_data['Temeperature 2'],marker='o',linestyle='-')
plt.show()

# %%
plt.figure(figsize=(13,8))
plt.scatter(data['Temeperature 1'],data['Time'])
plt.show()
